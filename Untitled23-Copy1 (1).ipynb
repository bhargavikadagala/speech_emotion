# %%
#IMPORT THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
# to play the audio files
import IPython.display as ipd
from IPython.display import Audio
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %%
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import tensorflow as tf 
print ("Done")
# Out:
# Done

# %% [markdown]
# # Importing Data

# %% [markdown]
# #                                              Ravdess Dataframe
# Here is the filename identifiers as per the official RAVDESS website:
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# * Vocal channel (01 = speech, 02 = song).
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# So, here's an example of an audio filename. 02-01-06-01-02-01-12.mp4 This means the meta data for the audio file is:
#
# * Video-only (02)
# * Speech (01)
# * Fearful (06)
# * Normal intensity (01)
# * Statement "dogs" (02)
# * 1st Repetition (01)
# * 12th Actor (12) - Female (as the actor ID number is even)

# %%
#preparing data set

ravdess =r'C:\\Users\\91630\\Downloads\\soundfiles\\'
ravdess_directory_list = os.listdir(ravdess)
print(ravdess_directory_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15']

# %% [markdown]
# # Preprocessing

# %%
file_emotion = []
file_path = []
for i in ravdess_directory_list:
    actor = os.listdir(ravdess + i)
    for f in actor:
        parts = f.split('.')[0].split('-')
        if len(parts) >= 3:
            file_emotion.append(int(parts[2]))
            file_path.append(ravdess + i + '/' + f)

# %%
print(actor[0])
print(parts[0])
print(file_path[0])
print(int(parts[2]))
print(f)
# Out:
# 03-01-01-01-01-01-15.wav
# 03
# C:\\Users\\91630\\Downloads\\soundfiles\\Actor_01/03-01-01-01-01-01-01.wav
# 8
# 03-01-08-02-01-01-15.wav

# %%
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
ravdess_df = pd.concat([emotion_df, path_df], axis=1)
# changing integers to actual emotions.
ravdess_df.Emotions.replace({1:'Neutral', 2:'Calm', 3:'Happy', 4:'Sad', 5:'Angry', 6:'Fear', 7:'Disgust',
                             8:'Surprise'},
                            inplace=True)
print(ravdess_df.head())
print("______________________________________________")
print(ravdess_df.tail())
print("_______________________________________________")
print(ravdess_df.Emotions.value_counts())
# Out:
#   Emotions                                               Path
# 0  Neutral  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 1     Calm  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 2     Calm  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 3    Happy  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 4    Happy  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# ______________________________________________
#      Emotions                                               Path
# 220      Fear  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 221   Disgust  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 222   Disgust  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 223  Surprise  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# 224  Surprise  C:\\Users\\91630\\Downloads\\soundfiles\\Actor...
# _______________________________________________
# Calm        30
# Happy       30
# Sad         30
# Angry       30
# Fear        30
# Disgust     30
# Surprise    30
# Neutral     15
# Name: Emotions, dtype: int64

# %% [markdown]
#                           Data Visualisation and Exploration

# %%
#First let's plot the count of each emotions in our dataset.
# import sbn
plt.figure(figsize=(12, 5))
plt.title('Count of Emotions', size=16)
sns.countplot(data=ravdess_df, x='Emotions')
plt.ylabel('Count', size=14)
plt.xlabel('Emotions', size=14)
plt.xticks(rotation=45)
plt.show()

# %%
data,sr = librosa.load(file_path[0])
sr
# Out:
# 22050

# %%
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
plt.figure(figsize=(10, 5))
spectrogram = librosa.feature.melspectrogram(y=data, sr=sr, n_mels=128,fmax=8000) 
log_spectrogram = librosa.power_to_db(spectrogram)
librosa.display.specshow(log_spectrogram, y_axis='mel', sr=sr, x_axis='time');
plt.title('Mel Spectrogram ')
plt.colorbar(format='%+2.0f dB')

# %%
mfcc = librosa.feature.mfcc(y=data, sr=sr, n_mfcc=30)


# MFCC
plt.figure(figsize=(16, 10))
plt.subplot(3,1,1)
librosa.display.specshow(mfcc, x_axis='time')
plt.ylabel('MFCC')
plt.colorbar()

ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Data augmentation

# %%
# NOISE
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data
# STRETCH
def stretch(data):
    return librosa.effects.time_stretch(data, rate=0.8)
# SHIFT
def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)
# PITCH
def pitch(data, sampling_rate, pitch_factor):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_factor)

# %%
# NORMAL AUDIO
import librosa.display
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=data, sr=sr)
ipd.Audio(data,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# AUDIO WITH NOISE
x = noise(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# STRETCHED AUDIO
x = stretch(data)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# SHIFTED AUDIO
x = shift(data)
plt.figure(figsize=(12,5))
librosa.display.waveshow(y=x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x = pitch(data, sr, 0.7)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(x, sr=sr)
ipd.Audio(x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature extraction

# %%
def feat_ext(data):
    #Time_domain_features
    # ZCR Persody features or Low level ascoustic features
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally
    #Frequency_domain_features
    #Spectral and wavelet Features
    #MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sr,n_mfcc=40).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally
    return result

def get_feat(path):
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    # normal data
    res1 = feat_ext(data)
    result = np.array(res1)
    #data with noise
    noise_data = noise(data)
    res2 = feat_ext(noise_data)
    result = np.vstack((result, res2))
    #data with stretch and pitch
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = feat_ext(data_stretch_pitch)
    result = np.vstack((result, res3))
    return result

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  8

# %% [markdown]
# # Faster way to get features
# ***Parallel way***
#
# **Dont be afraid from red lines that not Normal**
#
#
# * In this modified code, the get_features function is defined to get features for a single audio file. The function takes the file path and its corresponding emotion as input and returns two lists: X, which contains the features for the audio file, and Y, which contains the emotion label.
#
# * Then, the Parallel function from joblib library is used to call the get_features function in parallel for all audio files. The n_jobs parameter is set to -1 to use all available CPU cores.
#
# * Finally, the results from all parallel calls to get_features are concatenated into X and Y lists.

# %%
# PITCH
def pitch(data, sampling_rate=sr, n_steps=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=n_steps)

# %%
from joblib import Parallel, delayed
import timeit
start = timeit.default_timer()
# Define a function to get features for a single audio file
def get_features(path, emotion):
    feature = get_feat(path)
    X, Y = [], []
    for ele in feature:
        ele_pitched = pitch(ele, sampling_rate=sr, n_steps=0.7)
        X.append(ele_pitched)
        Y.append(emotion)
    return X, Y

# %%
# Call the get_features function in parallel for all audio files

X, Y = [], []
results = Parallel(n_jobs=-1)(
    delayed(get_features)(path, emotion) for path, emotion in zip(ravdess_df['Path'], ravdess_df['Emotions'])
)
for result in results:
    X.extend(result[0])
    Y.extend(result[1])
stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# Time:  17.125941799999964

# %% [markdown]
# # Saving features

# %%
Emotions = pd.DataFrame(X)
Emotions['Emotions'] = Y
Emotions.to_csv('emotion.csv', index=False)
Emotions.head()
# Out:
#            0           1          2          3         4          5  \
# 0 -51.446316 -467.143829  49.078255  12.689854 -1.860531  23.526770
# 1 -32.029617 -312.440399  19.023548  14.532194 -3.228827  13.786722
# 2 -56.546936 -515.904297  47.053085  13.277466 -3.632038  23.649406
# 3 -52.896061 -470.565399  59.607815  14.769629  0.713854  23.969856
# 4 -35.552475 -346.027618  22.426882  18.663185 -2.771390  16.116434
#
#            6          7          8         9  ...        32        33  \
# 0 -19.014019  15.057114 -23.716536  6.417122  ...  0.398447 -5.172383
# 1 -12.559108   8.193843 -16.920673  4.147059  ...  0.107300 -3.438008
# 2 -22.216352  15.487265 -27.418724  8.779763  ... -0.410688 -5.547475
# 3 -18.414612  13.821733 -24.645988  5.819234  ...  0.429456 -5.558730
# 4 -12.312140   9.602454 -17.466110  5.219821  ...  0.207866 -3.110445
#
#          34        35        36        37        38        39        40  \
# 0 -0.130406 -3.725851  1.270868 -5.207133 -0.669400 -2.151854  1.674636
# 1  0.060086 -2.063521  0.232633 -2.751608 -0.711856 -1.702832  1.136379
# 2 -0.213237 -3.824129 -1.282976 -5.520066 -0.665850 -3.218648  2.232443
# 3  1.790367 -3.857524  0.671122 -5.368596 -2.013473 -2.798469  1.918022
# 4  0.682999 -2.727204  0.068203 -3.663309 -1.267460 -2.147914  1.366469
#
#    Emotions
# 0   Neutral
# 1   Neutral
# 2   Neutral
# 3      Calm
# 4      Calm
#
# [5 rows x 42 columns]

# %%
Emotions = pd.read_csv('./emotion.csv')
Emotions.head()
# Out:
#            0           1          2          3         4          5  \
# 0 -51.446316 -467.143829  49.078255  12.689854 -1.860531  23.526770
# 1 -39.211868 -370.129822  30.324982  13.603260 -2.454918  17.441828
# 2 -56.546936 -515.904297  47.053085  13.277466 -3.632038  23.649406
# 3 -52.896061 -470.565399  59.607815  14.769629  0.713854  23.969856
# 4 -39.069939 -373.525177  29.241146  18.634018 -2.369299  17.347765
#
#            6          7          8         9  ...        32        33  \
# 0 -19.014019  15.057114 -23.716536  6.417122  ...  0.398447 -5.172383
# 1 -15.190423  10.178944 -21.292568  4.233438  ...  0.199514 -4.418588
# 2 -22.216352  15.487265 -27.418724  8.779763  ... -0.410688 -5.547475
# 3 -18.414612  13.821733 -24.645988  5.819234  ...  0.429456 -5.558730
# 4 -14.494555   9.647627 -19.747351  5.623777  ...  0.102746 -3.673746
#
#          34        35        36        37        38        39        40  \
# 0 -0.130406 -3.725851  1.270868 -5.207133 -0.669400 -2.151854  1.674636
# 1 -0.540230 -2.660767  0.598073 -3.900961 -1.133528 -2.079773  1.399183
# 2 -0.213237 -3.824129 -1.282976 -5.520066 -0.665850 -3.218648  2.232443
# 3  1.790367 -3.857524  0.671122 -5.368596 -2.013473 -2.798469  1.918022
# 4  0.608701 -3.138873 -0.078390 -3.944591 -1.737687 -2.558256  1.576876
#
#    Emotions
# 0   Neutral
# 1   Neutral
# 2   Neutral
# 3      Calm
# 4      Calm
#
# [5 rows x 42 columns]

# %% [markdown]
# # Data preparation

# %%
#taking all rows and all cols without last col for X which include features
#taking last col for Y, which include the emotions


X = Emotions.iloc[: ,:-1].values
Y = Emotions['Emotions'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y
from sklearn.preprocessing import StandardScaler, OneHotEncoder
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
print(Y.shape)
X.shape
# Out:
# (675, 8)
# (675, 41)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((506, 41), (506, 8), (169, 41), (169, 8))

# %% [markdown]
# # CNN model

# %%
#reshape for lstm
X_train = x_train.reshape(x_train.shape[0] , x_train.shape[1] , 1)
X_test = x_test.reshape(x_test.shape[0] , x_test.shape[1] , 1)

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((506, 41), (506, 8), (169, 41), (169, 8))

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM,BatchNormalization , GRU
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,mode='auto')
es=EarlyStopping(monitor='val_accuracy', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
#Reshape for CNN_LSTM MODEL

x_traincnn =np.expand_dims(x_train, axis=2)
x_testcnn= np.expand_dims(x_test, axis=2)
x_traincnn.shape, y_train.shape, x_testcnn.shape, y_test.shape
#x_testcnn[0]
# Out:
# ((506, 41, 1), (506, 8), (169, 41, 1), (169, 8))

# %%
#CNN


model = Sequential()
model.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
model.add(BatchNormalization())

model.add(LSTM(256, return_sequences=True))

model.add(LSTM(128))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(8, activation='softmax'))

optimiser = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 41, 2048)          12288
#
#  max_pooling1d (MaxPooling1D  (None, 21, 2048)         0
#  )
#
#  batch_normalization (BatchN  (None, 21, 2048)         8192
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 21, 1024)          10486784
#
#  max_pooling1d_1 (MaxPooling  (None, 11, 1024)         0
#  1D)
#
#  batch_normalization_1 (Batc  (None, 11, 1024)         4096
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 11, 512)           2621952
#
#  max_pooling1d_2 (MaxPooling  (None, 6, 512)           0
#  1D)
#
#  batch_normalization_2 (Batc  (None, 6, 512)           2048
#  hNormalization)
#
#  lstm (LSTM)                 (None, 6, 256)            787456
#
#  lstm_1 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 8)                 264
#
# =================================================================
# Total params: 14,147,048
# Trainable params: 14,139,880
# Non-trainable params: 7,168
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model( model, show_shapes=True, show_layer_names=True, to_file='model.png')
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
#CNN
history =  model.fit(x_traincnn, y_train, batch_size=64, epochs=100, validation_data=(x_testcnn, y_test))
# Out:
# Epoch 1/100
# 8/8 [==============================] - 41s 4s/step - loss: 2.0662 - accuracy: 0.1759 - val_loss: 2.0779 - val_accuracy: 0.1361
# Epoch 2/100
# 8/8 [==============================] - 23s 3s/step - loss: 2.0320 - accuracy: 0.1996 - val_loss: 2.0687 - val_accuracy: 0.1243
# Epoch 3/100
# 8/8 [==============================] - 23s 3s/step - loss: 2.0137 - accuracy: 0.2134 - val_loss: 2.0945 - val_accuracy: 0.1361
# Epoch 4/100
# 8/8 [==============================] - 23s 3s/step - loss: 2.0230 - accuracy: 0.2134 - val_loss: 2.0813 - val_accuracy: 0.1598
# Epoch 5/100
# 8/8 [==============================] - 24s 3s/step - loss: 1.9862 - accuracy: 0.2194 - val_loss: 2.0802 - val_accuracy: 0.1361
# Epoch 6/100
# 8/8 [==============================] - 24s 3s/step - loss: 1.9557 - accuracy: 0.2391 - val_loss: 2.0863 - val_accuracy: 0.1065
# Epoch 7/100
# 8/8 [==============================] - 24s 3s/step - loss: 1.9427 - accuracy: 0.2411 - val_loss: 2.0892 - val_accuracy: 0.1361
# Epoch 8/100
# 8/8 [==============================] - 24s 3s/step - loss: 1.9305 - accuracy: 0.2352 - val_loss: 2.0999 - val_accuracy: 0.1598
# Epoch 9/100
# 8/8 [==============================] - 23s 3s/step - loss: 1.8501 - accuracy: 0.3063 - val_loss: 2.0968 - val_accuracy: 0.1302
# Epoch 10/100
# 8/8 [==============================] - 23s 3s/step - loss: 1.8371 - accuracy: 0.2866 - val_loss: 2.1303 - val_accuracy: 0.1243
# Epoch 11/100
# 8/8 [==============================] - 24s 3s/step - loss: 1.7826 - accuracy: 0.2846 - val_loss: 2.0886 - val_accuracy: 0.1420
# Epoch 12/100
# 8/8 [==============================] - 23s 3s/step - loss: 1.7399 - accuracy: 0.3340 - val_loss: 2.1472 - val_accuracy: 0.1243
# Epoch 13/100
# 8/8 [==============================] - 23s 3s/step - loss: 1.7523 - accuracy: 0.3557 - val_loss: 2.1461 - val_accuracy: 0.1243
# Epoch 14/100
# 8/8 [==============================] - 23s 3s/step - loss: 1.7215 - accuracy: 0.3597 - val_loss: 2.1485 - val_accuracy: 0.1183
# Epoch 15/100
# 8/8 [==============================] - 23s 3s/step - loss: 1.6652 - accuracy: 0.3834 - val_loss: 2.1525 - val_accuracy: 0.1065
# Epoch 16/100
# 8/8 [==============================] - 22s 3s/step - loss: 1.5729 - accuracy: 0.4071 - val_loss: 2.1157 - val_accuracy: 0.1065
# Epoch 17/100
# 8/8 [==============================] - 22s 3s/step - loss: 1.5542 - accuracy: 0.4012 - val_loss: 2.1996 - val_accuracy: 0.1361
# Epoch 18/100
# 8/8 [==============================] - 22s 3s/step - loss: 1.4641 - accuracy: 0.4664 - val_loss: 2.2437 - val_accuracy: 0.1243
# Epoch 19/100
# 8/8 [==============================] - 22s 3s/step - loss: 1
100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0685 - accuracy: 0.9901 - val_loss: 3.8098 - val_accuracy: 0.4024
# Epoch 78/100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0684 - accuracy: 0.9862 - val_loss: 3.2196 - val_accuracy: 0.4615
# Epoch 79/100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0633 - accuracy: 0.9783 - val_loss: 2.7552 - val_accuracy: 0.5207
# Epoch 80/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.1586 - accuracy: 0.9763 - val_loss: 3.6702 - val_accuracy: 0.4970
# Epoch 81/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.0565 - accuracy: 0.9901 - val_loss: 3.3925 - val_accuracy: 0.5089
# Epoch 82/100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0703 - accuracy: 0.9743 - val_loss: 3.2625 - val_accuracy: 0.5148
# Epoch 83/100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0553 - accuracy: 0.9862 - val_loss: 3.2494 - val_accuracy: 0.4675
# Epoch 84/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.1130 - accuracy: 0.9822 - val_loss: 2.9523 - val_accuracy: 0.4675
# Epoch 85/100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0596 - accuracy: 0.9842 - val_loss: 3.3036 - val_accuracy: 0.4911
# Epoch 86/100
# 8/8 [==============================] - 18s 2s/step - loss: 0.0374 - accuracy: 0.9901 - val_loss: 3.2716 - val_accuracy: 0.5325
# Epoch 87/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.0906 - accuracy: 0.9842 - val_loss: 3.3442 - val_accuracy: 0.5207
# Epoch 88/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.1056 - accuracy: 0.9763 - val_loss: 2.4543 - val_accuracy: 0.5799
# Epoch 89/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.0885 - accuracy: 0.9862 - val_loss: 3.0209 - val_accuracy: 0.5562
# Epoch 90/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.0597 - accuracy: 0.9921 - val_loss: 3.1611 - val_accuracy: 0.5562
# Epoch 91/100
# 8/8 [==============================] - 19s 2s/step - loss: 0.1440 - accuracy: 0.9684 - val_loss: 3.0003 - val_accuracy: 0.5325
# Epoch 92/100
# 8/8 [==============================] - 20s 2s/step - loss: 0.1615 - accuracy: 0.9763 - val_loss: 3.6285 - val_accuracy: 0.5385
# Epoch 93/100
# 8/8 [==============================] - 22s 3s/step - loss: 0.1345 - accuracy: 0.9605 - val_loss: 2.8447 - val_accuracy: 0.5207
# Epoch 94/100
# 8/8 [==============================] - 23s 3s/step - loss: 0.1529 - accuracy: 0.9644 - val_loss: 2.3489 - val_accuracy: 0.5030
# Epoch 95/100
# 8/8 [==============================] - 24s 3s/step - loss: 0.1242 - accuracy: 0.9723 - val_loss: 2.4055 - val_accuracy: 0.5621
# Epoch 96/100
# 8/8 [==============================] - 22s 3s/step - loss: 0.1375 - accuracy: 0.9783 - val_loss: 2.5859 - val_accuracy: 0.5621
# Epoch 97/100
# 8/8 [==============================] - 21s 3s/step - loss: 0.1225 - accuracy: 0.9704 - val_loss: 2.8123 - val_accuracy: 0.5089
# Epoch 98/100
# 8/8 [==============================] - 22s 3s/step - loss: 0.1296 - accuracy: 0.9723 - val_loss: 3.0693 - val_accuracy: 0.5089
# Epoch 99/100
# 8/8 [==============================] - 22s 3s/step - loss: 0.0841 - accuracy: 0.9802 - val_loss: 3.2216 - val_accuracy: 0.4852
# Epoch 100/100
# 8/8 [==============================] - 22s 3s/step - loss: 0.0590 - accuracy: 0.9921 - val_loss: 2.9921 - val_accuracy: 0.5030

# %%
print("Accuracy of our model on test data : " , model.evaluate(x_testcnn,y_test)[1]*100 , "%")
# Out:
# 6/6 [==============================] - 1s 58ms/step - loss: 2.9921 - accuracy: 0.5030
# Accuracy of our model on test data :  50.295859575271606 %

# %% [markdown]
# # Some plots of multi_model

# %%
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()

# %%
# predicting on test data.
pred_test = model.predict(x_testcnn)
y_pred = encoder.inverse_transform(pred_test)
y_test1 = encoder.inverse_transform(y_test)

# Check for random predictions
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test1.flatten()

df.head(10)
# Out:
# 6/6 [==============================] - 2s 55ms/step
#   Predicted Labels Actual Labels
# 0         Surprise         Angry
# 1            Happy          Fear
# 2          Disgust       Disgust
# 3             Calm          Calm
# 4             Fear      Surprise
# 5          Disgust       Disgust
# 6              Sad           Sad
# 7            Angry         Happy
# 8            Angry         Angry
# 9             Fear      Surprise

# %%
# # MLP for Pima Indians Dataset Serialize to JSON and HDF5
# from tensorflow.keras.models import Sequential, model_from_json
# model_json = model000.to_json()
# with open("cnnlstmmodel.json", "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# model00.save_weights("cnnlstmmodel000.h5")
# print("Saved model to disk")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define your MLP model
model = Sequential()
model.add(Dense(64, input_dim=8, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile and train the model on your data
# ...
# ...

# Serialize model to JSON
model_json = model.to_json()
with open("mlp_model.json", "w") as json_file:
    json_file.write(model_json)

# Serialize weights to HDF5
model.save_weights("mlp_model_weights.h5")

print("Saved model to disk")
# Out:
# Saved model to disk

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\91630

# %%
from tensorflow.keras.models import Sequential, model_from_json
json_file = open(r'C:\Users\91630\mlp_model.json')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights(r"C:\Users\91630\mlp_model_weights.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
from tensorflow.keras.optimizers import SGD

# %%
from tensorflow.keras.optimizers import legacy

# %%
from tensorflow.keras.optimizers import SGD

optimizer = SGD(learning_rate=0.001, momentum=0.8)
loaded_model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
score = loaded_model.evaluate(x_testcnn, y_test)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))

# %% [markdown]
# # Saving and Loading our Stnadrad Scaler and encoder
# * To save the StandardScaler object to use it later in a Flask API

# %%
import joblib

#saving scaler
joblib.dump(scaler, 'scaler.joblib')

#loading our scaler

scaler = joblib.load('scaler.joblib')

#saving our encoder

joblib.dump(encoder, 'encoder.joblib')

#loading our encoder

encoder= joblib.load('encoder.joblib')

# %% [markdown]
# # Predict function
# * That can predict new record

# %%
def get_predict_feat(path):
    d, s_rate= librosa.load(path, duration=2.5, offset=0.6)
    res=feat_ext(d)
    result=np.array(res)
    result=np.reshape(result,newshape=(1,41))
    i_result = scaler.transform(result)
    final_result=np.expand_dims(i_result, axis=2)
    
    return final_result

# %%
res=get_predict_feat(r"C:\Users\91630\Downloads\soundfiles\Actor_01\03-01-01-01-01-01-01.wav")
print(res.shape)
# Out:
# (1, 41, 1)

# %%
emotions1={1:'Neutral', 2:'Calm', 3:'Happy', 4:'Sad', 5:'Angry', 6:'Fear', 7:'Disgust',8:'Surprise'}
def prediction(path1):
    res=get_predict_feat(path1)
    predictions=loaded_model.predict(res)
    y_pred = encoder.inverse_transform(predictions)
    print(y_pred[0][0])

# %%
prediction(r"C:\Users\91630\Downloads\soundfiles\Actor_05\03-01-02-01-01-01-05.wav")
# Out:
# 1/1 [==============================] - 0s 48ms/step
# Calm

# %%
prediction(r"C:\Users\91630\Downloads\soundfiles\Actor_21\03-01-04-02-01-02-21.wav")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# Sad
